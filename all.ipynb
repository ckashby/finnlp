# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore") 

from nltk.tokenize import sent_tokenize, RegexpTokenizer
from nltk.stem import WordNetLemmatizer
# from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
# from nltk.sentiment.vader import SentimentIntensityAnalyzer
import re
import nltk
import yfinance as yf

# %%
['MERC', 'BAYRY', 'SNY', 'AZN', 'BMY', 'NVO', 'NVS']
# Out:
# ['MERC', 'BAYRY', 'SNY', 'AZN', 'BMY', 'NVO', 'NVS']

# %%
merc_tick = yf.Ticker('MERC')
merc_hist = merc_tick.history(period='6y')
merc_hist['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
bayry_tick = yf.Ticker('BAYRY')
bayry_hist = bayry_tick.history(period='6y')
bayry_hist['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
sny_tick = yf.Ticker('SNY')
sny_hist = sny_tick.history(period='6y')
sny_hist['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
azn_tick = yf.Ticker('AZN')
azn_hist = azn_tick.history(period='6y')
azn_hist['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
bmy_tick = yf.Ticker('BMY')
bmy_hist = bmy_tick.history(period='6y')
bmy_hist['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# combine all the graphs into one graph
plt.plot(merc_hist['Close'], label='MERC')
plt.plot(bayry_hist['Close'], label='BAYRY')
plt.plot(sny_hist['Close'], label='SNY')
plt.plot(azn_hist['Close'], label='AZN')
plt.plot(bmy_hist['Close'], label='BMY')
plt.legend()
plt.title('Pharmaceutical Companies Stock Prices 2018 - 2024')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.savefig('./images/pharma_stock_prices_2018_2024.png')
